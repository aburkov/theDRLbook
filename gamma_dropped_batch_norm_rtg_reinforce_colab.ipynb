# %% [markdown]
# <a href="https://colab.research.google.com/github/aburkov/theDRLbook/blob/main/gamma_dropped_batch_norm_rtg_reinforce_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # REINFORCE with Return Normalization in Python
#
# In this notebook, we implement REINFORCE with return normalization: we sample a batch of $N$ trajectories with the same, unchanged policy, gather the reward-to-go values from all timesteps of all trajectories, subtract their batch mean, divide by their batch standard deviation, and only then build the policy loss. We test it on the problem of landing a space rocket booster on a floating platform. For this, we will use the `PlatformLander` environment.

# %%
# !command -v swig >/dev/null || (apt-get -qq update > /dev/null && apt-get -qq install -y swig > /dev/null)
# !python -m pip install --no-cache-dir platform_lander==0.1.12
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Collecting platform_lander==0.1.12
#   Downloading platform_lander-0.1.12-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from platform_lander==0.1.12) (2.0.2)
# Collecting box2d-py>=2.3.5 (from platform_lander==0.1.12)
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 kB 63.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1 in /usr/local/lib/python3.12/dist-packages (from platform_lander==0.1.12) (2.6.1)
# Downloading platform_lander-0.1.12-py3-none-any.whl (18 kB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp312-cp312-linux_x86_64.whl size=2381960 sha256=525e01c435c59d00bb34ff55e61f77b9131659739443d659e9d382bd5727bf01
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0vzve848/wheels/d6/3c/ab/b6fd75459cadc56f4a4125d4cb387a708a59ca8589e4cc6b7d
# Successfully built box2d-py
# Installing collected packages: box2d-py, platform_lander
# Successfully installed box2d-py-2.3.8 platform_lander-0.1.12

# %%
import csv
import math
import time
from collections import deque
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.distributions import Categorical

from platform_lander import PlatformLander
from platform_lander.platform_lander import (
    BOOSTER_BOTTOM,
    BOOSTER_START_CLEARANCE,
    SCALE,
    apply_booster_initial_impulse,
    sample_booster_start_angle,
)

RUNS_DIR = Path('/content/runs') if Path('/content').exists() else Path('runs')
RUNS_DIR.mkdir(parents=True, exist_ok=True)

EPISODES = 100_000
MAX_STEPS = 400
GAMMA = 0.99
LEARNING_RATE = 5e-3
BATCH_SIZE = 50
HIDDEN_DIM = 64
SEED = 0
TARGET_WINDOW = 50
PRINT_EVERY = 250
SAVE_EVERY = 1_000
NO_EARLY_STOP = False
RANDOM_BOOSTER_START_X = False

ENABLE_WIND = True
WIND_POWER = 3.0
SUCCESS_REWARD = 1000.0
FAILURE_REWARD = -300.0
SHAPING_FACTOR = 1.0
MAX_JET_FIRES = 50

LOG_FILE = RUNS_DIR / 'gamma_dropped_batch_norm_rtg_reinforce.log'
MODEL_FILE = RUNS_DIR / 'gamma_dropped_batch_norm_rtg_reinforce.pt'
BEST_MODEL_FILE = RUNS_DIR / 'gamma_dropped_batch_norm_rtg_reinforce_best.pt'
CSV_FILE = RUNS_DIR / 'gamma_dropped_batch_norm_rtg_reinforce.csv'


def platform_lander_reward_kwargs() -> dict[str, float | int]:
    return {
        'success_reward': float(SUCCESS_REWARD),
        'failure_reward': float(FAILURE_REWARD),
        'shaping_factor': float(SHAPING_FACTOR),
        'max_jet_fires': int(MAX_JET_FIRES),
    }


def platform_lander_kwargs(*, render_mode: str | None = None) -> dict[str, object]:
    kwargs: dict[str, object] = {
        'enable_wind': ENABLE_WIND,
        'wind_power': WIND_POWER,
        'wind_direction': (1.0, 0.0),
        **platform_lander_reward_kwargs(),
    }
    if render_mode is not None:
        kwargs['render_mode'] = render_mode
    return kwargs

# %%
import sys
import hashlib
from pathlib import Path

import torch
import numpy as np
import Box2D
import pygame
import platform_lander.platform_lander as pl
import importlib.metadata as md

print("python:", sys.version)
print("torch:", torch.__version__)
print("numpy:", np.__version__)
print("box2d:", Box2D.__version__)
print("pygame:", pygame.version.ver)
print("platform_lander dist:", md.version("platform_lander"))
print("platform_lander file:", pl.__file__)
print("platform_lander sha256:", hashlib.sha256(Path(pl.__file__).read_bytes()).hexdigest())
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# python: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# torch: 2.11.0+cpu
# numpy: 2.0.2
# box2d: 2.3.8
# pygame: 2.6.1
# platform_lander dist: 0.1.12
# platform_lander file: /usr/local/lib/python3.12/dist-packages/platform_lander/platform_lander.py
# platform_lander sha256: 4d6df1c935ea9f556476ccfea453b72f10bf62917371cccb802573a9fc741b67

# %%
import hashlib
import importlib.metadata as md
from pathlib import Path
import platform_lander.platform_lander as pl

print("dist version:", md.version("platform_lander"))
print("file:", pl.__file__)
print("sha256:", hashlib.sha256(Path(pl.__file__).read_bytes()).hexdigest())
# Out:
# dist version: 0.1.12
# file: /usr/local/lib/python3.12/dist-packages/platform_lander/platform_lander.py
# sha256: 4d6df1c935ea9f556476ccfea453b72f10bf62917371cccb802573a9fc741b67

# %% [markdown]
# ## Platform Lander
#
# The environment contains a reusable booster falling from space and a moving ocean platform where the booster should land. The booster has three controllable jets: one main jet at the bottom and two smaller attitude-control jets near the top, one on each side. Firing the bottom jet pushes the booster upward and helps slow its descent. Firing one of the top side jets creates a torque, rotating the booster clockwise or counterclockwise. The agent must learn when to fire these jets so that the booster descends slowly, stays upright, tracks the moving platform, and lands vertically.
#
# ![](https://raw.githubusercontent.com/aburkov/theDRLbook/main/test_environments/platform_lander/booster_landing_stages.png)
#
# The platform floats on the ocean and moves horizontally from left to right and back again. If the booster lands upright on the platform with low enough speed, the episode is considered successful. If it misses the platform and falls into the ocean, flies out of bounds, hits the platform with its body, or settles away from the platform, the episode fails.
#
# The environment also includes wind. This notebook uses the same environment configuration as the validation experiments in the chapter: wind is enabled and blows horizontally with power $3.0$, so the environment pushes the booster around in ways the agent cannot predict. The booster has $50$ available jet fires, so the agent cannot simply keep firing forever; it must learn to use thrust efficiently while guiding the booster toward the moving platform.
#
# Rewards in this environment are designed to encourage the booster to approach the platform, slow down, stay upright, and conserve fuel.
#
# At each step, the environment computes a shaping score based on the current state. The score subtracts horizontal distance from the platform, vertical distance when the booster bottom is over the platform, horizontal and vertical speed, tilt, and angular velocity. It also gives a bonus of $12$ when the left landing foot touches the platform and another bonus of $12$ when the right landing foot touches the platform.
#
# The actual dense per-step reward is `SHAPING_FACTOR` times the change in this shaping score from the previous step. So the agent receives positive reward when it improves its situation, and negative reward when it gets farther from a good landing state.
#
# There is also a small fuel penalty whenever a jet is fired. Firing the bottom jet subtracts $0.30$, and firing one of the top attitude-control jets subtracts $0.03$.
#
# Finally, terminal rewards are assigned at the end of an episode:
#
# - successful vertical landing: $+1000$, multiplied by an impact-speed multiplier (a gentle touchdown earns the full reward; harder but still acceptable touchdowns earn as little as a quarter of it)
# - failure: $-300$
#
# These values—wind power $3.0$, $50$ jet fires, success reward $+1000$, failure reward $-300$, and shaping factor $1.0$—are the same ones used by the validation scripts whose results are reported in the chapter's Validation Results section.

# %% [markdown]
# ## Training a Platform Lander with Normalized Batch REINFORCE
#
# The `PlatformLander` environment has a discrete action space with four actions:
#
# ```text
# 0: do nothing
# 1: fire the upper-left attitude jet
# 2: fire the bottom engine
# 3: fire the upper-right attitude jet
# ```
#
# The observation is an 11-dimensional vector. It contains:
#
# ```text
# 0: booster x-position relative to the platform, normalized by half the viewport width
# 1: booster y-position relative to the target landing height, normalized by half the viewport height
# 2: booster x-velocity relative to the platform x-velocity, scaled by half viewport width / FPS
# 3: booster y-velocity, scaled by half viewport height / FPS
# 4: booster angle, normalized to [-pi, pi]
# 5: booster angular velocity, scaled by 20 / FPS
# 6: left landing foot contact flag, 1 if touching, else 0
# 7: right landing foot contact flag, 1 if touching, else 0
# 8: platform x-position, normalized relative to half the viewport width
# 9: platform x-velocity
# 10: fraction of jet fires remaining
# ```

# %%
env = PlatformLander(**platform_lander_kwargs())
observation, info = env.reset(seed=SEED)

print('observation_space:', env.observation_space)
print('action_space:', env.action_space)
print('initial observation shape:', observation.shape)
print('initial observation:', np.round(observation, 3))

env.close()
# Out:
# observation_space: Box([ -2.5        -2.5       -10.        -10.         -6.2831855 -10.
#    0.          0.         -1.         -2.          0.       ], [ 2.5        2.5       10.        10.         6.2831855 10.
#   1.         1.         1.         2.         1.       ], (11,), float32)
# action_space: Discrete(4)
# initial observation shape: (11,)
# initial observation: [ 0.     1.474 -0.416  0.147  0.032  0.     0.     0.    -0.358  0.383
#   1.   ]

# %% [markdown]
# Now we define the policy neural network. It's the same as in the [single-trajectory REINFORCE notebook](https://github.com/aburkov/theDRLbook/blob/main/gamma_dropped_rtg_reinforce_colab.ipynb):

# %%
def init_layer(layer, gain=math.sqrt(2), bias_const=0):
    nn.init.orthogonal_(layer.weight, gain) # ➊
    nn.init.constant_(layer.bias, bias_const)
    return layer

class Policy(nn.Module):
    def __init__(self, obs_dim, act_dim, hid_dim=64):
        super().__init__()
        self.net = nn.Sequential(
            init_layer(nn.Linear(obs_dim, hid_dim), math.sqrt(2)), # ➋
            nn.Tanh(), # ➌
            init_layer(nn.Linear(hid_dim, hid_dim), math.sqrt(2)), # ➍
            nn.Tanh(),
            init_layer(nn.Linear(hid_dim, act_dim), 0.01), # ➎
        )

    def forward(self, obs):
        return self.net(obs)

# %% [markdown]
# Now we define a function that will sample an action from the policy. It's the same as in the [single-trajectory REINFORCE notebook](https://github.com/aburkov/theDRLbook/blob/main/gamma_dropped_rtg_reinforce_colab.ipynb):

# %%
def sample_action(policy: Policy, observation: np.ndarray, *, train: bool = True) -> int:
    obs_tensor = torch.as_tensor(observation, dtype=torch.float32)
    logits = policy(obs_tensor)
    dist = Categorical(logits=logits)

    if train:
        action_tensor = dist.sample()
    else:
        action_tensor = torch.argmax(logits)

    return int(action_tensor.item())


# Tiny check with an untrained policy.
env = PlatformLander(**platform_lander_kwargs())
observation, _ = env.reset(seed=SEED)
policy = Policy(
    int(env.observation_space.shape[0]),
    int(env.action_space.n),
    HIDDEN_DIM,
)
action = sample_action(policy, observation)
print('sampled action:', action)
env.close()
# Out:
# sampled action: 2

# %% [markdown]
# During one episode, we store all observations, log-probabilities, and rewards.
#
# The code below is the same as in the [single-trajectory REINFORCE notebook](https://github.com/aburkov/theDRLbook/blob/main/gamma_dropped_rtg_reinforce_colab.ipynb):

# %%
def randomize_start(
    env: PlatformLander,
    rng: np.random.Generator,
    *,
    random_booster_start_x: bool = False,
) -> np.ndarray:
    """Randomize the platform and optionally the booster x position."""
    assert env.booster is not None
    assert env.platform is not None

    h = 400 / 30.0

    env.platform.position = (
        float(rng.uniform(env.platform_min_x, env.platform_max_x)),
        env.platform_y,
    )
    env.platform_direction = int(rng.choice([-1, 1]))
    env.platform.linearVelocity = (
        env.platform_speed * env.platform_direction,
        0.0,
    )

    booster_x = (
        float(rng.uniform(env.platform_min_x, env.platform_max_x))
        if random_booster_start_x
        else float(env.platform.position.x)
    )
    env.booster.position = (
        booster_x,
        float(h + BOOSTER_BOTTOM / SCALE + BOOSTER_START_CLEARANCE),
    )
    env.booster.angle = sample_booster_start_angle(rng)
    env.booster.linearVelocity = (0.0, 0.0)
    env.booster.angularVelocity = 0.0
    apply_booster_initial_impulse(env.booster, rng)
    env.booster.awake = True

    env.ocean_contact = False
    env.platform_contact = False
    env.body_platform_contact = False
    env.left_foot_contact = False
    env.right_foot_contact = False
    env.failure_reason = None
    env.prev_shaping = None
    env.bottom_flame_power = 0.0
    env.top_flame_power = 0.0
    env.top_flame_direction = 0
    env.jet_fires_used = 0
    return env._get_state()


def discounted_return(rewards: list[float], gamma: float) -> float:
    total = 0.0
    discount = 1.0
    for reward in rewards:
        total += discount * reward
        discount *= gamma
    return total


def run_episode_data(
    env: PlatformLander,
    policy: Policy,
    rng: np.random.Generator,
    *,
    gamma: float,
    max_steps: int,
    train: bool,
    random_booster_start_x: bool = False,
    reset_seed: int | None = None,
    start_seed: int | None = None,
) -> tuple[list[torch.Tensor], list[torch.Tensor], list[float], float, int, dict]:
    if reset_seed is None:
        reset_seed = int(rng.integers(0, 2**31 - 1))
    start_rng = np.random.default_rng(start_seed) if start_seed is not None else rng

    observation, _ = env.reset(seed=reset_seed)
    observation = randomize_start(
        env,
        start_rng,
        random_booster_start_x=random_booster_start_x,
    )

    observations: list[torch.Tensor] = []
    log_probs: list[torch.Tensor] = []
    rewards: list[float] = []
    entropies: list[float] = []
    info: dict = {}

    for step in range(max_steps):
        obs_tensor = torch.as_tensor(observation, dtype=torch.float32)
        observations.append(obs_tensor)
        logits = policy(obs_tensor)
        dist = Categorical(logits=logits)

        if train:
            action_tensor = dist.sample()
        else:
            action_tensor = torch.argmax(logits)

        action = int(action_tensor.item())
        log_probs.append(dist.log_prob(action_tensor))
        entropies.append(float(dist.entropy().detach().item()))

        observation, reward, terminated, truncated, info = env.step(action)
        rewards.append(float(reward))

        if terminated or truncated:
            break

    if not terminated and not truncated:
        rewards[-1] = float(env.failure_reward)
        info = {
            **info,
            'success': False,
            'failure_reason': 'timeout',
        }

    average_entropy = float(np.mean(entropies)) if entropies else 0.0
    info = {
        **info,
        'policy_entropy': average_entropy,
        'policy_perplexity': float(math.exp(average_entropy)),
    }

    episode_return = discounted_return(rewards, gamma)
    return observations, log_probs, rewards, episode_return, step + 1, info

# %% [markdown]
# After the episode ends, we compute a reward-to-go value for every timestep. The code below is the same as in the [single-trajectory REINFORCE notebook](https://github.com/aburkov/theDRLbook/blob/main/gamma_dropped_rtg_reinforce_colab.ipynb):

# %%
def rewards_to_go(rewards: list[float], gamma: float) -> torch.Tensor:
    returns = []
    running_return = 0.0

    for reward in reversed(rewards):
        running_return = reward + gamma * running_return
        returns.append(running_return)

    returns.reverse()
    return torch.as_tensor(returns, dtype=torch.float32)

# %% [markdown]
# Now we can form the normalized reward-to-go loss terms. We first compute the reward-to-go tensors for all trajectories in the batch, then normalize across the whole batch, then build the per-trajectory loss terms.
#
# In the code below:
#
# - In line ➊, we compute one reward-to-go tensor per trajectory; concatenating them gathers all $M$ values of the batch into a single tensor.
# - In line ➋, we compute the batch statistics $\mu$ and $\sigma$ over these values.
# - In line ➌, each trajectory's reward-to-go values are shifted and rescaled using the shared batch statistics, $\tilde{G}_t = (G_t - \mu)/(\sigma + \epsilon)$, where $\epsilon = 10^{-8}$ prevents division by zero in the special case where every reward-to-go value in the batch is identical.
#
# After this transformation, the values multiplying the log-probabilities have mean $0$ and standard deviation (approximately) $1$, regardless of the reward scale of the environment. The loss terms are then averaged and passed to `backward()` and `step()` exactly as in batch REINFORCE.

# %%
def batch_normalized_loss_terms(
    batch_log_probs: list[list[torch.Tensor]],
    batch_rewards: list[list[float]],
    *,
    gamma: float,
) -> tuple[list[torch.Tensor], float, float]:
    rtg_list = [rewards_to_go(rewards, gamma) for rewards in batch_rewards]  # ➊
    all_rtg = torch.cat(rtg_list)
    rtg_mean = all_rtg.mean()
    rtg_std = all_rtg.std(unbiased=False)  # ➋

    loss_terms: list[torch.Tensor] = []
    for log_probs, rtg in zip(batch_log_probs, rtg_list):
        log_prob_tensor = torch.stack(log_probs).reshape(-1)
        normalized_rtg = (rtg - rtg_mean) / (rtg_std + 1e-8)  # ➌
        normalized_rtg = normalized_rtg.to(
            device=log_prob_tensor.device,
            dtype=log_prob_tensor.dtype,
        )
        assert log_prob_tensor.shape == normalized_rtg.shape
        loss_terms.append(-(log_prob_tensor * normalized_rtg).sum())

    return loss_terms, float(rtg_mean.detach().item()), float(rtg_std.detach().item())

# %% [markdown]
# Finally, we perform one optimization step per batch.
#
# In the training loop below:
#
# - In line ➊, we run `BATCH_SIZE` complete episodes without updating the policy parameters between them.
# - In line ➋, we normalize the reward-to-go values across the whole batch and build one loss term per trajectory.
# - In line ➌, we average the per-trajectory losses; a single backward pass and optimizer step then apply the update.

# %%
def training_args() -> dict[str, object]:
    return {
        'episodes': EPISODES,
        'max_steps': MAX_STEPS,
        'gamma': GAMMA,
        'learning_rate': LEARNING_RATE,
        'batch_size': BATCH_SIZE,
        'hidden_dim': HIDDEN_DIM,
        'seed': SEED,
        'target_window': TARGET_WINDOW,
        'print_every': PRINT_EVERY,
        'save_every': SAVE_EVERY,
        'wind': ENABLE_WIND,
        'wind_power': WIND_POWER,
        'no_early_stop': NO_EARLY_STOP,
        'random_booster_start_x': RANDOM_BOOSTER_START_X,
        'success_reward': SUCCESS_REWARD,
        'failure_reward': FAILURE_REWARD,
        'shaping_factor': SHAPING_FACTOR,
        'max_jet_fires': MAX_JET_FIRES,
        'log_file': str(LOG_FILE),
        'model_file': str(MODEL_FILE),
        'best_model_file': str(BEST_MODEL_FILE),
        'csv_file': str(CSV_FILE),
    }


def open_log(log_file: Path):
    log_file.parent.mkdir(parents=True, exist_ok=True)
    return log_file.open('w', encoding='utf-8')


def log(message: str, log_file=None) -> None:
    print(message)
    if log_file is not None:
        log_file.write(message + '\n')
        log_file.flush()


def save_training_csv(rows: list[dict[str, object]], csv_file: Path) -> Path:
    csv_file.parent.mkdir(parents=True, exist_ok=True)
    fieldnames: list[str] = []
    for row in rows:
        for key in row:
            if key not in fieldnames:
                fieldnames.append(key)

    with csv_file.open('w', encoding='utf-8', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(rows)

    return csv_file


def save_policy(policy: Policy, model_file: Path, *, obs_dim: int, action_dim: int) -> Path:
    model_file.parent.mkdir(parents=True, exist_ok=True)
    torch.save(
        {
            'policy_state_dict': policy.state_dict(),
            'obs_dim': obs_dim,
            'action_dim': action_dim,
            'hidden_dim': HIDDEN_DIM,
            'args': training_args(),
        },
        model_file,
    )
    return model_file


def save_checkpoint(
    policy: Policy,
    training_rows: list[dict[str, object]],
    *,
    obs_dim: int,
    action_dim: int,
    log_file,
    episode: int,
) -> tuple[Path, Path]:
    model_path = save_policy(policy, MODEL_FILE, obs_dim=obs_dim, action_dim=action_dim)
    csv_path = save_training_csv(training_rows, CSV_FILE)
    log(f'saved_checkpoint episode={episode} model_file={model_path} csv_file={csv_path}', log_file)
    return model_path, csv_path


def save_best_checkpoint(
    policy: Policy,
    *,
    obs_dim: int,
    action_dim: int,
    log_file,
    episode: int,
    success_count: int,
    average_return: float,
) -> Path:
    best_model_path = save_policy(policy, BEST_MODEL_FILE, obs_dim=obs_dim, action_dim=action_dim)
    log(
        f'saved_best_checkpoint episode={episode} '
        f'success{TARGET_WINDOW}={success_count} '
        f'avg{TARGET_WINDOW}={average_return:.2f} '
        f'model_file={best_model_path}',
        log_file,
    )
    return best_model_path


def clear_existing_best_checkpoint(log_file) -> None:
    if BEST_MODEL_FILE.exists():
        BEST_MODEL_FILE.unlink()
        log(f'cleared_best_checkpoint model_file={BEST_MODEL_FILE}', log_file)


def train() -> tuple[Policy, pd.DataFrame]:
    torch.manual_seed(SEED)
    rng = np.random.default_rng(SEED)

    env = PlatformLander(**platform_lander_kwargs())

    policy = Policy(
        int(env.observation_space.shape[0]),
        int(env.action_space.n),
        HIDDEN_DIM,
    )
    obs_dim = int(env.observation_space.shape[0])
    action_dim = int(env.action_space.n)

    optimizer = torch.optim.SGD(policy.parameters(), lr=LEARNING_RATE)

    recent_returns: deque[float] = deque(maxlen=TARGET_WINDOW)
    recent_successes: deque[bool] = deque(maxlen=TARGET_WINDOW)
    recent_jet_fires: deque[int] = deque(maxlen=TARGET_WINDOW)
    recent_entropies: deque[float] = deque(maxlen=TARGET_WINDOW)

    training_rows: list[dict[str, object]] = []
    log_file = open_log(LOG_FILE)
    model_path: Path | None = None
    best_model_path: Path | None = None
    csv_path: Path | None = None
    episode = 0
    completed_episode = 0
    last_saved_episode = 0
    best_success_count = 0
    stop_training = False
    learning_started_at = time.perf_counter()
    elapsed_seconds = 0.0

    try:
        log(
            f'training_start script=gamma_dropped_batch_norm_rtg_reinforce '
            f'episodes={EPISODES} batch_size={BATCH_SIZE} max_steps={MAX_STEPS} seed={SEED} '
            f'model_file={MODEL_FILE}',
            log_file,
        )
        clear_existing_best_checkpoint(log_file)

        while episode < EPISODES and not stop_training:
            batch_log_probs: list[list[torch.Tensor]] = []
            batch_rewards: list[list[float]] = []
            batch_metadata: list[tuple[int, float, int, dict]] = []

            for _ in range(BATCH_SIZE):  # ➊
                if episode >= EPISODES:
                    break
                episode += 1
                observations, log_probs, rewards, episode_return, steps, info = run_episode_data(
                    env,
                    policy,
                    rng,
                    gamma=GAMMA,
                    max_steps=MAX_STEPS,
                    train=True,
                    random_booster_start_x=RANDOM_BOOSTER_START_X,
                )
                batch_log_probs.append(log_probs)
                batch_rewards.append(rewards)
                batch_metadata.append((episode, episode_return, steps, info))

            if not batch_log_probs:
                break

            loss_terms, rtg_mean, rtg_std = batch_normalized_loss_terms(
                batch_log_probs,
                batch_rewards,
                gamma=GAMMA,
            )  # ➋
            loss = torch.stack(loss_terms).mean()  # ➌
            batch_loss = float(loss.detach().item())

            batch_rows: list[dict[str, object]] = []
            for (episode_number, episode_return, steps, info), trajectory_loss in zip(
                batch_metadata, loss_terms
            ):
                recent_returns.append(episode_return)
                recent_successes.append(bool(info.get('success', False)))
                recent_jet_fires.append(int(info.get('jet_fires_used', 0)))
                policy_entropy = float(info.get('policy_entropy', 0.0))
                recent_entropies.append(policy_entropy)

                average_return = float(np.mean(recent_returns))
                success_count = int(sum(recent_successes))
                average_jet_fires = float(np.mean(recent_jet_fires))
                average_entropy = float(np.mean(recent_entropies))

                batch_rows.append(
                    {
                        'episode': episode_number,
                        'return': episode_return,
                        'average_return': average_return,
                        'policy_loss': float(trajectory_loss.detach().item()),
                        'loss': batch_loss,
                        'success_count': success_count,
                        'success_rate': success_count / len(recent_successes),
                        'jet_fires': int(info.get('jet_fires_used', 0)),
                        'average_jet_fires': average_jet_fires,
                        'policy_entropy': policy_entropy,
                        'average_policy_entropy': average_entropy,
                        'effective_actions': float(math.exp(policy_entropy)),
                        'average_effective_actions': float(math.exp(average_entropy)),
                        'steps': steps,
                        'success': bool(info.get('success', False)),
                        'failure_reason': info.get('failure_reason'),
                        'batch_rtg_mean': rtg_mean,
                        'batch_rtg_std': rtg_std,
                    }
                )

                if episode_number == 1 or episode_number % PRINT_EVERY == 0:
                    log(
                        f'episode={episode_number:6d} '
                        f'return={episode_return:8.2f} '
                        f'avg{len(recent_returns):02d}={average_return:8.2f} '
                        f'success{len(recent_successes):02d}={success_count:2d} '
                        f'fires={info.get("jet_fires_used", 0):3d} '
                        f'entropy={policy_entropy:5.3f} '
                        f'steps={steps:4d} '
                        f'failure={info.get("failure_reason")}',
                        log_file,
                    )

            full_success_window = len(recent_successes) == TARGET_WINDOW
            success_count = int(sum(recent_successes))
            average_return = float(np.mean(recent_returns))
            if full_success_window and success_count > best_success_count:
                best_success_count = success_count
                best_model_path = save_best_checkpoint(
                    policy,
                    obs_dim=obs_dim,
                    action_dim=action_dim,
                    log_file=log_file,
                    episode=episode,
                    success_count=success_count,
                    average_return=average_return,
                )

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            training_rows.extend(batch_rows)
            completed_episode = episode

            if full_success_window and success_count == TARGET_WINDOW and not NO_EARLY_STOP:
                log(
                    f'early_stop episode={episode} '
                    f'success{TARGET_WINDOW}={success_count} '
                    f'avg{TARGET_WINDOW}={average_return:.2f} '
                    f'best_model_file={best_model_path}',
                    log_file,
                )
                stop_training = True

            if SAVE_EVERY and episode // SAVE_EVERY > (episode - len(batch_rows)) // SAVE_EVERY:
                model_path, csv_path = save_checkpoint(
                    policy,
                    training_rows,
                    obs_dim=obs_dim,
                    action_dim=action_dim,
                    log_file=log_file,
                    episode=episode,
                )
                last_saved_episode = episode

    except KeyboardInterrupt:
        log(f'training_interrupted episode={completed_episode}', log_file)

    finally:
        if training_rows and completed_episode != last_saved_episode:
            model_path, csv_path = save_checkpoint(
                policy,
                training_rows,
                obs_dim=obs_dim,
                action_dim=action_dim,
                log_file=log_file,
                episode=completed_episode,
            )
        elapsed_seconds = time.perf_counter() - learning_started_at
        if training_rows:
            training_rows[-1]['elapsed_seconds'] = elapsed_seconds
        log(
            f'learning_finished episode={completed_episode} '
            f'elapsed_seconds={elapsed_seconds:.2f} '
            f'elapsed_minutes={elapsed_seconds / 60.0:.2f}',
            log_file,
        )
        env.close()
        log_file.close()

    if not training_rows or model_path is None or csv_path is None:
        raise RuntimeError('training produced no episodes to save')

    return policy, pd.DataFrame(training_rows)

# %% [markdown]
# Run the training cell below. The hyperparameters match the stability-validation scripts used for the chapter's Validation Results section: $100{,}000$ episodes, batch size $50$, learning rate $5 \times 10^{-3}$, and seed $0$. Note how much larger this learning rate is than the one the single-episode and plain batch algorithms can tolerate—normalization pins the learning signal to mean $0$ and standard deviation $1$, which is what makes such large steps usable. For a quick demonstration, change `EPISODES` near the top of the notebook to a smaller value such as `1_000`, then run the training cell.
#
# Unlike the validation scripts, the notebook stops early once the policy lands successfully $50$ times in a row; set `NO_EARLY_STOP = True` to train through the full episode budget like the validation runs.

# %%
policy, history = train()
history.tail()
# Out:
# training_start script=gamma_dropped_batch_norm_rtg_reinforce episodes=100000 batch_size=50 max_steps=400 seed=0 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt
# episode=     1 return= -355.30 avg01= -355.30 success01= 0 fires= 50 entropy=1.386 steps= 400 failure=timeout
# saved_best_checkpoint episode=150 success50=1 avg50=-254.68 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode=   250 return=  -98.87 avg50= -245.24 success50= 1 fires= 50 entropy=1.360 steps= 253 failure=ocean
# episode=   500 return= -265.36 avg50= -258.82 success50= 0 fires= 50 entropy=1.365 steps= 183 failure=booster_body_hit_platform
# episode=   750 return= -108.31 avg50= -256.46 success50= 1 fires= 50 entropy=1.312 steps= 183 failure=ocean
# episode=  1000 return= -179.99 avg50= -196.25 success50= 2 fires= 50 entropy=1.320 steps= 177 failure=ocean
# saved_best_checkpoint episode=1000 success50=2 avg50=-196.25 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# saved_checkpoint episode=1000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode=  1250 return= -158.41 avg50= -199.46 success50= 0 fires= 50 entropy=1.343 steps= 121 failure=ocean
# saved_best_checkpoint episode=1400 success50=4 avg50=-165.84 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode=  1500 return= -286.75 avg50= -188.47 success50= 3 fires= 50 entropy=1.317 steps= 142 failure=ocean
# episode=  1750 return= -126.99 avg50= -163.01 success50= 1 fires= 50 entropy=1.293 steps= 222 failure=ocean
# episode=  2000 return= -129.48 avg50= -189.97 success50= 1 fires= 50 entropy=1.284 steps= 226 failure=ocean
# saved_checkpoint episode=2000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode=  2250 return= -136.99 avg50= -175.42 success50= 2 fires= 50 entropy=1.315 steps= 157 failure=booster_body_hit_platform
# episode=  2500 return=  -81.32 avg50= -174.31 success50= 1 fires= 50 entropy=1.300 steps= 182 failure=ocean
# saved_best_checkpoint episode=2600 success50=5 avg50=-109.70 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode=  2750 return= -144.50 avg50= -152.74 success50= 2 fires= 50 entropy=1.330 steps= 115 failure=ocean
# episode=  3000 return=  -26.79 avg50= -113.56 success50= 7 fires= 50 entropy=1.291 steps= 177 failure=ocean
# saved_best_checkpoint episode=3000 success50=7 avg50=-113.56 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# saved_checkpoint episode=3000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode=  3250 return=  136.68 avg50= -144.83 success50= 2 fires= 50 entropy=1.354 steps= 281 failure=None
# episode=  3500 return= -114.47 avg50= -113.62 success50= 3 fires= 50 entropy=1.311 steps= 129 failure=ocean
# episode=  3750 return= -196.24 avg50=  -72.66 success50= 8 fires= 50 entropy=1.270 steps= 119 failure=ocean
# saved_best_checkpoint episode=3750 success50=8 avg50=-72.66 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode=  4000 return= -127.48 avg50=  -89.36 success50= 7 fires= 50 entropy=1.294 steps= 144 failure=ocean
# saved_checkpoint episode=4000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# saved_best_checkpoint episode=4050 success50=10 avg50=-58.11 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode=  4250 return= -156.66 avg50= -111.12 success50= 4 fires= 50 entropy=1.249 steps= 116 failure=ocean
# saved_best_checkpoint episode=4400 success50=16 avg50=-0.52 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode=  4500 return=  -83.38 avg50=  -95.49 success50= 6 fires= 50 entropy=1.264 steps= 150 failure=ocean
# episode=  4750 return=  334.46 avg50=  -52.24 success50= 8 fires= 50 entropy=1.318 steps= 131 failure=None
# episode=  5000 return=   70.25 avg50=  -44.55 success50= 9 fires= 50 entropy=1.352 steps= 400 failure=timeout
# saved_checkpoint episode=5000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode=  5250 return= -205.36 avg50=  -12.66 success50=13 fires= 50 entropy=1.186 steps= 113 failure=ocean
# episode=  5500 return=  370.72 avg50=  -14.88 success50=14 fires= 47 entropy=1.226 steps=  79 failure=None
# saved_best_checkpoint episode=5700 success50=20 avg50=54.68 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode=  5750 return=  174.51 avg50=   65.48 success50=21 fires= 50 entropy=1.263 steps= 153 failure=None
# saved_best_checkpoint episode=5750 success50=21 avg50=65.48 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode=  6000 return=  -76.30 avg50=   52.59 success50=19 fires= 50 entropy=1.201 steps= 187 failure=booster_body_hit_platform
# saved_checkpoint episode=6000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# saved_best_checkpoint episode=6050 success50=22 avg50=96.16 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# saved_best_checkpoint episode=6100 success50=27 avg50=111.30 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode=  6250 return= -214.41 avg50=  -33.28 success50=10 fires= 50 entropy=1.221 steps= 110 failure=ocean
# episode=  6500 return=  295.22 avg50=   74.13 success50=22 fires= 40 entropy=1.183 steps=  75 failure=None
# episode=  6750 return=  316.34 avg50=  162.42 success50=30 fires= 43 entropy=1.173 steps=  79 failure=None
# saved_best_checkpoint episode=6750 success50=30 avg50=162.42 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode=  7000 return=  227.90 avg50=   99.01 success50=24 fires= 50 entropy=1.227 steps= 143 failure=None
# saved_checkpoint episode=7000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode=  7250 return=   53.68 avg50=   75.38 success50=20 fires= 50 entropy=1.323 steps= 400 failure=timeout
# episode=  7500 return=  -68.72 avg50=  140.02 success50=26 fires= 50 entropy=1.084 steps= 137 failure=booster_body_hit_platform
# episode=  7750 return=  313.00 avg50=  132.46 success50=23 fires= 29 entropy=1.118 steps=  73 failure=None
# episode=  8000 return=  322.67 avg50=  155.28 success50=32 fires= 45 entropy=1.135 steps=  83 failure=None
# saved_best_checkpoint episode=8000 success50=32 avg50=155.28 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# saved_checkpoint episode=8000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode=  8250 return=  333.48 avg50=  115.46 success50=25 fires= 36 entropy=1.151 steps=  67 failure=None
# episode=  8500 return=   77.14 avg50=  133.55 success50=25 fires= 50 entropy=1.296 steps= 400 failure=timeout
# episode=  8750 return= -166.96 avg50=   68.91 success50=20 fires= 41 entropy=1.138 steps=  73 failure=ocean
# episode=  9000 return= -190.43 avg50=  207.21 success50=34 fires= 50 entropy=1.036 steps= 118 failure=ocean
# saved_best_checkpoint episode=9000 success50=34 avg50=207.21 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# saved_checkpoint episode=9000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode=  9250 return=  -96.80 avg50=  121.59 success50=26 fires= 50 entropy=1.166 steps=  98 failure=ocean
# episode=  9500 return=  348.02 avg50=  163.34 success50=29 fires= 49 entropy=1.145 steps=  85 failure=None
# saved_best_checkpoint episode=9700 success50=36 avg50=216.94 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode=  9750 return=  -97.49 avg50=  116.16 success50=25 fires= 50 entropy=1.140 steps= 108 failure=ocean
# episode= 10000 return=  300.04 avg50=  133.21 success50=26 fires= 50 entropy=1.164 steps=  98 failure=None
# saved_checkpoint episode=10000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 10250 return=  292.71 avg50=  245.02 success50=38 fires= 50 entropy=1.129 steps=  87 failure=None
# saved_best_checkpoint episode=10250 success50=38 avg50=245.02 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode= 10500 return= -159.68 avg50=  173.65 success50=29 fires= 45 entropy=1.077 steps=  77 failure=ocean
# episode= 10750 return= -182.64 avg50=  170.74 success50=29 fires= 42 entropy=1.104 steps=  80 failure=ocean
# episode= 11000 return=  313.81 avg50=  183.67 success50=30 fires= 49 entropy=1.133 steps=  87 failure=None
# saved_checkpoint episode=11000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 11250 return=  396.58 avg50=  218.49 success50=34 fires= 40 entropy=1.114 steps=  76 failure=None
# episode= 11500 return=  257.62 avg50=  186.61 success50=30 fires= 47 entropy=1.104 steps=  89 failure=None
# episode= 11750 return=  337.10 avg50=  176.95 success50=27 fires= 41 entropy=1.156 steps=  73 failure=None
# episode= 12000 return=  387.34 avg50=  231.34 success50=35 fires= 37 entropy=1.095 steps=  81 failure=None
# saved_checkpoint episode=12000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 12250 return= -122.83 avg50=  187.75 success50=29 fires= 39 entropy=1.079 steps=  78 failure=ocean
# episode= 12500 return=  280.06 avg50=  217.32 success50=35 fires= 46 entropy=1.094 steps=  91 failure=None
# saved_best_checkpoint episode=12700 success50=39 avg50=243.12 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode= 12750 return=  330.88 avg50=  181.32 success50=30 fires= 48 entropy=1.090 steps=  81 failure=None
# episode= 13000 return=   70.20 avg50=  243.91 success50=35 fires= 50 entropy=1.290 steps= 400 failure=timeout
# saved_checkpoint episode=13000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 13250 return=   93.73 avg50=  218.52 success50=33 fires= 50 entropy=1.301 steps= 400 failure=timeout
# episode= 13500 return=  311.90 avg50=  203.33 success50=31 fires= 50 entropy=1.169 steps= 140 failure=None
# episode= 13750 return=  346.95 avg50=  233.08 success50=33 fires= 46 entropy=1.064 steps=  86 failure=None
# episode= 14000 return=  445.99 avg50=  150.20 success50=26 fires= 38 entropy=1.103 steps=  71 failure=None
# saved_checkpoint episode=14000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 14250 return=  401.76 avg50=  245.30 success50=33 fires= 38 entropy=1.086 steps=  72 failure=None
# episode= 14500 return=   91.80 avg50=  193.75 success50=31 fires= 50 entropy=1.277 steps= 400 failure=timeout
# episode= 14750 return=  -20.25 avg50=  189.14 success50=29 fires= 50 entropy=1.228 steps= 161 failure=ocean
# episode= 15000 return=   74.74 avg50=  208.43 success50=29 fires= 50 entropy=1.298 steps= 400 failure=timeout
# saved_checkpoint episode=15000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 15250 return=  343.00 avg50=  242.48 success50=36 fires= 29 entropy=1.055 steps=  64 failure=None
# episode= 15500 return=   62.89 avg50=  235.95 success50=36 fires= 50 entropy=1.319 steps= 400 failure=timeout
# episode= 15750 return=  376.10 avg50=  249.78 success50=36 fires= 50 entropy=1.179 steps= 117 failure=None
# episode= 16000 return=  408.56 avg50=  250.43 success50=35 fires= 50 entropy=1.109 steps= 103 failure=None
# saved_checkpoint episode=16000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 16250 return=  391.55 avg50=  210.83 success50=30 fires= 48 entropy=1.125 steps=  84 failure=None
# episode= 16500 return=  411.58 avg50=  299.90 success50=40 fires= 49 entropy=1.071 steps=  98 failure=None
# saved_best_checkpoint episode=16500 success50=40 avg50=299.90 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode= 16750 return=  472.84 avg50=  232.28 success50=33 fires= 36 entropy=1.088 steps=  71 failure=None
# episode= 17000 return=   89.14 avg50=  216.51 success50=31 fires= 50 entropy=1.271 steps= 400 failure=timeout
# saved_checkpoint episode=17000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 17250 return=  -30.27 avg50=  223.14 success50=31 fires= 50 entropy=1.058 steps= 239 failure=booster_body_hit_platform
# episode= 17500 return=  360.67 avg50=  225.94 success50=33 fires= 37 entropy=1.103 steps=  64 failure=None
# episode= 17750 return=  -34.54 avg50=  183.45 success50=26 fires= 50 entropy=1.165 steps= 120 failure=ocean
# episode= 18000 return=   46.40 avg50=  223.92 success50=32 fires= 50 entropy=1.265 steps= 400 failure=timeout
# saved_checkpoint episode=18000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 18250 return=  445.87 avg50=  205.65 success50=30 fires= 50 entropy=1.087 steps=  91 failure=None
# episode= 18500 return=   41.65 avg50=  237.97 success50=34 fires= 50 entropy=1.119 steps= 400 failure=timeout
# episode= 18750 return=  293.71 avg50=  237.28 success50=32 fires= 50 entropy=1.115 steps= 120 failure=None
# episode= 19000 return=  424.99 avg50=  289.41 success50=39 fires= 37 entropy=1.059 steps=  76 failure=None
# saved_checkpoint episode=19000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 19250 return=  323.79 avg50=  273.47 success50=35 fires= 50 entropy=1.125 steps=  98 failure=None
# episode= 19500 return=   62.52 avg50=  238.38 success50=34 fires= 50 entropy=1.309 steps= 400 failure=timeout
# episode= 19750 return=  274.60 avg50=  219.19 success50=32 fires= 50 entropy=1.111 steps=  95 failure=None
# episode= 20000 return= -142.76 avg50=  248.47 success50=34 fires= 36 entropy=1.084 steps=  71 failure=ocean
# saved_checkpoint episode=20000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 20250 return=  510.49 avg50=  265.23 success50=36 fires= 43 entropy=1.089 steps=  71 failure=None
# episode= 20500 return=  353.53 avg50=  241.89 success50=31 fires= 44 entropy=1.024 steps=  78 failure=None
# episode= 20750 return=  401.04 avg50=  226.82 success50=29 fires= 43 entropy=1.056 steps=  91 failure=None
# episode= 21000 return=  238.54 avg50=  238.98 success50=34 fires= 41 entropy=1.021 steps=  92 failure=None
# saved_checkpoint episode=21000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 21250 return=   55.50 avg50=  255.65 success50=32 fires= 50 entropy=1.278 steps= 400 failure=timeout
# episode= 21500 return=  406.61 avg50=  251.98 success50=32 fires= 50 entropy=1.115 steps=  99 failure=None
# episode= 21750 return=  396.64 avg50=  272.67 success50=37 fires= 34 entropy=1.020 steps=  71 failure=None
# episode= 22000 return=  360.84 avg50=  311.18 success50=40 fires= 40 entropy=1.023 steps=  79 failure=None
# saved_checkpoint episode=22000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 22250 return=  331.66 avg50=  230.32 success50=32 fires= 40 entropy=1.063 steps=  77 failure=None
# episode= 22500 return=  289.69 avg50=  255.37 success50=32 fires= 50 entropy=1.137 steps= 113 failure=None
# episode= 22750 return=  409.71 avg50=  254.86 success50=35 fires= 50 entropy=1.098 steps=  93 failure=None
# episode= 23000 return=  -15.92 avg50=  288.26 success50=38 fires= 50 entropy=1.136 steps= 132 failure=ocean
# saved_checkpoint episode=23000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 23250 return=  354.01 avg50=  266.74 success50=37 fires= 47 entropy=1.018 steps=  81 failure=None
# episode= 23500 return=  336.40 avg50=  267.03 success50=36 fires= 50 entropy=1.075 steps= 106 failure=None
# episode= 23750 return=  -80.47 avg50=  246.33 success50=33 fires= 40 entropy=1.087 steps=  77 failure=ocean
# episode= 24000 return=  447.75 avg50=  295.62 success50=40 fires= 50 entropy=1.089 steps=  82 failure=None
# saved_checkpoint episode=24000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 24250 return=  354.92 avg50=  284.93 success50=37 fires= 48 entropy=1.062 steps=  83 failure=None
# episode= 24500 return=  356.31 avg50=  269.85 success50=37 fires= 48 entropy=1.104 steps=  91 failure=None
# saved_best_checkpoint episode=24550 success50=42 avg50=335.56 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode= 24750 return=  416.01 avg50=  299.41 success50=40 fires= 31 entropy=1.062 steps=  69 failure=None
# episode= 25000 return=  390.82 avg50=  324.17 success50=40 fires= 47 entropy=1.130 steps=  96 failure=None
# saved_checkpoint episode=25000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 25250 return=   63.40 avg50=  270.01 success50=35 fires= 50 entropy=1.304 steps= 400 failure=timeout
# episode= 25500 return=  -70.55 avg50=  262.84 success50=35 fires= 50 entropy=1.089 steps= 102 failure=ocean
# episode= 25750 return=  463.43 avg50=  285.24 success50=35 fires= 50 entropy=1.159 steps= 106 failure=None
# episode= 26000 return=  427.14 avg50=  250.08 success50=34 fires= 42 entropy=1.070 steps=  72 failure=None
# saved_checkpoint episode=26000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# saved_best_checkpoint episode=26100 success50=43 avg50=354.95 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode= 26250 return=  347.66 avg50=  320.38 success50=40 fires= 48 entropy=1.085 steps=  93 failure=None
# episode= 26500 return=  358.49 avg50=  230.98 success50=33 fires= 39 entropy=1.014 steps=  78 failure=None
# episode= 26750 return=  347.25 avg50=  260.43 success50=35 fires= 38 entropy=1.070 steps=  76 failure=None
# episode= 27000 return=  406.43 avg50=  328.26 success50=41 fires= 50 entropy=1.090 steps=  84 failure=None
# saved_checkpoint episode=27000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 27250 return=  364.44 avg50=  295.33 success50=37 fires= 41 entropy=1.091 steps=  81 failure=None
# episode= 27500 return=  416.71 avg50=  336.61 success50=42 fires= 43 entropy=1.118 steps=  93 failure=None
# episode= 27750 return=  486.06 avg50=  324.95 success50=42 fires= 40 entropy=1.081 steps=  88 failure=None
# episode= 28000 return=  471.05 avg50=  304.42 success50=38 fires= 43 entropy=1.101 steps=  74 failure=None
# saved_checkpoint episode=28000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 28250 return=  447.29 avg50=  316.46 success50=40 fires= 37 entropy=1.093 steps=  80 failure=None
# episode= 28500 return=  373.35 avg50=  331.57 success50=41 fires= 38 entropy=1.050 steps=  83 failure=None
# episode= 28750 return=  444.83 avg50=  311.80 success50=39 fires= 47 entropy=1.107 steps=  85 failure=None
# episode= 29000 return=  440.82 avg50=  344.58 success50=45 fires= 43 entropy=1.072 steps=  90 failure=None
# saved_best_checkpoint episode=29000 success50=45 avg50=344.58 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# saved_checkpoint episode=29000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 29250 return=   83.74 avg50=  334.61 success50=42 fires= 50 entropy=1.008 steps= 400 failure=timeout
# episode= 29500 return=   62.35 avg50=  309.64 success50=36 fires= 50 entropy=1.314 steps= 400 failure=timeout
# episode= 29750 return=  409.31 avg50=  320.26 success50=40 fires= 50 entropy=1.118 steps=  89 failure=None
# episode= 30000 return=  362.68 avg50=  324.76 success50=40 fires= 42 entropy=1.127 steps=  88 failure=None
# saved_checkpoint episode=30000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 30250 return=  414.54 avg50=  269.68 success50=36 fires= 50 entropy=1.132 steps=  96 failure=None
# episode= 30500 return= -112.40 avg50=  291.31 success50=38 fires= 50 entropy=1.133 steps= 120 failure=ocean
# episode= 30750 return=  453.65 avg50=  311.44 success50=37 fires= 50 entropy=1.125 steps=  89 failure=None
# episode= 31000 return=  407.27 avg50=  349.92 success50=41 fires= 50 entropy=1.170 steps= 102 failure=None
# saved_checkpoint episode=31000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 31250 return=  256.43 avg50=  344.47 success50=44 fires= 50 entropy=1.135 steps= 131 failure=None
# episode= 31500 return=  422.25 avg50=  321.21 success50=38 fires= 48 entropy=1.099 steps=  89 failure=None
# episode= 31750 return=  456.22 avg50=  301.46 success50=37 fires= 40 entropy=1.119 steps=  80 failure=None
# episode= 32000 return=  483.66 avg50=  316.75 success50=39 fires= 49 entropy=1.055 steps=  85 failure=None
# saved_checkpoint episode=32000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 32250 return=  476.36 avg50=  347.71 success50=40 fires= 41 entropy=1.097 steps=  78 failure=None
# episode= 32500 return=  387.93 avg50=  302.41 success50=39 fires= 50 entropy=1.110 steps= 125 failure=None
# episode= 32750 return=  341.47 avg50=  321.22 success50=40 fires= 50 entropy=1.074 steps= 100 failure=None
# episode= 33000 return=   54.42 avg50=  318.89 success50=40 fires= 50 entropy=1.029 steps= 400 failure=timeout
# saved_checkpoint episode=33000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 33250 return=  375.90 avg50=  308.84 success50=37 fires= 50 entropy=1.108 steps= 115 failure=None
# saved_best_checkpoint episode=33450 success50=46 avg50=387.54 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode= 33500 return=  468.44 avg50=  288.76 success50=36 fires= 50 entropy=1.094 steps=  94 failure=None
# episode= 33750 return=  478.78 avg50=  362.05 success50=45 fires= 44 entropy=1.068 steps=  78 failure=None
# episode= 34000 return=  462.69 avg50=  332.68 success50=41 fires= 37 entropy=1.043 steps=  90 failure=None
# saved_checkpoint episode=34000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 34250 return=  396.24 avg50=  329.85 success50=39 fires= 30 entropy=1.035 steps=  70 failure=None
# episode= 34500 return=  377.13 avg50=  346.70 success50=43 fires= 44 entropy=1.047 steps=  81 failure=None
# episode= 34750 return=  -29.10 avg50=  350.57 success50=42 fires= 50 entropy=1.094 steps= 113 failure=ocean
# episode= 35000 return=  381.70 avg50=  318.59 success50=39 fires= 41 entropy=1.000 steps=  85 failure=None
# saved_checkpoint episode=35000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# saved_best_checkpoint episode=35050 success50=47 avg50=376.27 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode= 35250 return=  390.70 avg50=  379.06 success50=46 fires= 50 entropy=1.036 steps= 112 failure=None
# episode= 35500 return=  384.00 avg50=  365.24 success50=41 fires= 30 entropy=0.990 steps=  81 failure=None
# episode= 35750 return=   -0.82 avg50=  276.57 success50=34 fires= 50 entropy=0.642 steps= 400 failure=timeout
# episode= 36000 return=  313.05 avg50=  357.05 success50=43 fires= 50 entropy=1.059 steps= 120 failure=None
# saved_checkpoint episode=36000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 36250 return=  415.46 avg50=  364.63 success50=45 fires= 47 entropy=1.011 steps=  82 failure=None
# episode= 36500 return=  379.68 avg50=  309.25 success50=38 fires= 50 entropy=0.993 steps= 105 failure=None
# episode= 36750 return=  391.27 avg50=  308.40 success50=38 fires= 38 entropy=0.991 steps=  91 failure=None
# episode= 37000 return=  -70.28 avg50=  350.65 success50=43 fires= 49 entropy=1.077 steps=  83 failure=ocean
# saved_checkpoint episode=37000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 37250 return=  452.34 avg50=  315.25 success50=40 fires= 41 entropy=1.043 steps=  81 failure=None
# episode= 37500 return=  348.85 avg50=  363.25 success50=45 fires= 47 entropy=1.050 steps= 103 failure=None
# episode= 37750 return=  419.49 avg50=  368.60 success50=45 fires= 41 entropy=1.040 steps=  84 failure=None
# episode= 38000 return=  395.85 avg50=  387.57 success50=46 fires= 37 entropy=1.033 steps=  77 failure=None
# saved_checkpoint episode=38000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 38250 return=  404.78 avg50=  354.80 success50=43 fires= 43 entropy=1.074 steps=  90 failure=None
# saved_best_checkpoint episode=38350 success50=48 avg50=398.51 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode= 38500 return=  369.76 avg50=  392.17 success50=47 fires= 41 entropy=1.096 steps=  81 failure=None
# episode= 38750 return=  380.04 avg50=  340.20 success50=42 fires= 45 entropy=1.033 steps= 100 failure=None
# episode= 39000 return=  431.66 avg50=  338.72 success50=43 fires= 35 entropy=1.018 steps=  85 failure=None
# saved_checkpoint episode=39000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 39250 return= -143.25 avg50=  317.66 success50=40 fires= 50 entropy=0.932 steps= 150 failure=ocean
# episode= 39500 return=  435.43 avg50=  330.22 success50=41 fires= 33 entropy=1.046 steps=  76 failure=None
# episode= 39750 return=  374.86 avg50=  341.19 success50=42 fires= 48 entropy=1.006 steps=  85 failure=None
# episode= 40000 return=  -13.70 avg50=  360.53 success50=42 fires= 50 entropy=1.136 steps= 132 failure=ocean
# saved_checkpoint episode=40000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 40250 return=  451.45 avg50=  390.18 success50=46 fires= 36 entropy=1.057 steps=  76 failure=None
# episode= 40500 return=  364.55 avg50=  339.99 success50=41 fires= 48 entropy=1.085 steps=  84 failure=None
# episode= 40750 return=  493.61 avg50=  370.59 success50=44 fires= 36 entropy=1.078 steps=  70 failure=None
# episode= 41000 return=  425.34 avg50=  340.38 success50=42 fires= 41 entropy=1.072 steps=  76 failure=None
# saved_checkpoint episode=41000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 41250 return=  343.60 avg50=  372.39 success50=45 fires= 28 entropy=0.970 steps=  84 failure=None
# episode= 41500 return=  329.03 avg50=  361.04 success50=45 fires= 50 entropy=1.043 steps= 133 failure=None
# episode= 41750 return=  471.33 avg50=  392.34 success50=48 fires= 50 entropy=1.062 steps=  87 failure=None
# episode= 42000 return=  422.50 avg50=  357.70 success50=43 fires= 30 entropy=1.047 steps=  78 failure=None
# saved_checkpoint episode=42000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 42250 return=  462.96 avg50=  382.31 success50=46 fires= 35 entropy=1.080 steps=  74 failure=None
# episode= 42500 return=  353.76 avg50=  345.66 success50=43 fires= 50 entropy=1.072 steps= 133 failure=None
# saved_best_checkpoint episode=42700 success50=49 avg50=392.24 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# episode= 42750 return=  285.41 avg50=  376.19 success50=46 fires= 50 entropy=1.112 steps= 144 failure=None
# episode= 43000 return=  365.59 avg50=  376.93 success50=45 fires= 46 entropy=1.048 steps=  81 failure=None
# saved_checkpoint episode=43000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 43250 return=  396.95 avg50=  382.79 success50=46 fires= 49 entropy=1.054 steps= 105 failure=None
# episode= 43500 return=  364.80 avg50=  355.47 success50=44 fires= 50 entropy=1.100 steps=  89 failure=None
# episode= 43750 return=  452.26 avg50=  369.44 success50=46 fires= 45 entropy=1.112 steps=  84 failure=None
# episode= 44000 return=  426.00 avg50=  394.84 success50=46 fires= 26 entropy=1.094 steps=  70 failure=None
# saved_checkpoint episode=44000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 44250 return=  374.07 avg50=  348.88 success50=43 fires= 50 entropy=1.054 steps= 102 failure=None
# episode= 44500 return=  452.63 avg50=  311.76 success50=38 fires= 34 entropy=1.058 steps=  79 failure=None
# episode= 44750 return=  457.74 avg50=  353.91 success50=42 fires= 45 entropy=1.064 steps=  83 failure=None
# episode= 45000 return=  431.94 avg50=  411.18 success50=49 fires= 43 entropy=1.066 steps=  76 failure=None
# saved_checkpoint episode=45000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 45250 return=   92.73 avg50=  360.94 success50=44 fires= 50 entropy=1.144 steps= 400 failure=timeout
# episode= 45500 return=  433.15 avg50=  404.50 success50=46 fires= 44 entropy=1.080 steps=  85 failure=None
# episode= 45750 return=  431.76 avg50=  404.48 success50=48 fires= 48 entropy=1.088 steps=  86 failure=None
# episode= 46000 return=  409.28 avg50=  406.94 success50=49 fires= 37 entropy=1.062 steps=  85 failure=None
# saved_checkpoint episode=46000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 46250 return=  371.56 avg50=  379.59 success50=46 fires= 36 entropy=1.023 steps=  88 failure=None
# episode= 46500 return=  424.93 avg50=  387.31 success50=47 fires= 50 entropy=1.034 steps=  87 failure=None
# episode= 46750 return=  364.07 avg50=  355.36 success50=43 fires= 41 entropy=1.032 steps=  82 failure=None
# episode= 47000 return=  366.21 avg50=  385.84 success50=46 fires= 40 entropy=0.983 steps=  82 failure=None
# saved_checkpoint episode=47000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 47250 return=  451.61 avg50=  376.06 success50=47 fires= 34 entropy=1.076 steps=  73 failure=None
# episode= 47500 return=  330.47 avg50=  388.87 success50=47 fires= 48 entropy=1.040 steps=  97 failure=None
# episode= 47750 return=  346.89 avg50=  371.45 success50=45 fires= 50 entropy=1.027 steps= 119 failure=None
# episode= 48000 return=  473.28 avg50=  377.58 success50=45 fires= 39 entropy=1.046 steps=  78 failure=None
# saved_checkpoint episode=48000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 48250 return=  412.21 avg50=  379.37 success50=46 fires= 49 entropy=1.086 steps=  85 failure=None
# episode= 48500 return=  455.81 avg50=  336.41 success50=41 fires= 47 entropy=1.073 steps=  74 failure=None
# episode= 48750 return=  494.05 avg50=  369.63 success50=44 fires= 33 entropy=1.035 steps=  78 failure=None
# episode= 49000 return=  420.99 avg50=  390.41 success50=46 fires= 38 entropy=1.064 steps=  78 failure=None
# saved_checkpoint episode=49000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 49250 return=  412.51 avg50=  387.25 success50=46 fires= 50 entropy=1.112 steps=  90 failure=None
# episode= 49500 return=  340.43 avg50=  358.02 success50=43 fires= 44 entropy=1.048 steps=  88 failure=None
# episode= 49750 return=  440.72 avg50=  371.59 success50=44 fires= 43 entropy=1.078 steps=  84 failure=None
# episode= 50000 return=  509.96 avg50=  364.95 success50=44 fires= 46 entropy=1.097 steps=  77 failure=None
# saved_checkpoint episode=50000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 50250 return=  419.80 avg50=  342.44 success50=41 fires= 50 entropy=1.100 steps=  89 failure=None
# episode= 50500 return=  371.58 avg50=  398.39 success50=47 fires= 36 entropy=1.019 steps=  78 failure=None
# episode= 50750 return=   66.74 avg50=  389.89 success50=46 fires= 50 entropy=1.206 steps= 400 failure=timeout
# episode= 51000 return=  468.60 avg50=  402.31 success50=47 fires= 39 entropy=1.008 steps=  82 failure=None
# saved_checkpoint episode=51000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 51250 return=  339.84 avg50=  365.48 success50=45 fires= 50 entropy=1.039 steps= 129 failure=None
# episode= 51500 return=  486.62 avg50=  384.64 success50=47 fires= 46 entropy=1.029 steps=  83 failure=None
# episode= 51750 return=  410.96 avg50=  391.39 success50=47 fires= 31 entropy=0.995 steps=  83 failure=None
# episode= 52000 return=  383.80 avg50=  384.14 success50=48 fires= 33 entropy=1.028 steps=  93 failure=None
# saved_checkpoint episode=52000 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# episode= 52250 return=  167.76 avg50=  394.26 success50=48 fires= 50 entropy=0.844 steps= 181 failure=None
# saved_best_checkpoint episode=52300 success50=50 avg50=416.36 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# early_stop episode=52300 success50=50 avg50=416.36 best_model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce_best.pt
# saved_checkpoint episode=52300 model_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.pt csv_file=/content/runs/gamma_dropped_batch_norm_rtg_reinforce.csv
# learning_finished episode=52300 elapsed_seconds=7100.22 elapsed_minutes=118.34
#        episode      return  average_return  policy_loss       loss  \
# 52295    52296  400.993043      414.014710    56.664017  12.595065
# 52296    52297  432.056002      413.374984    38.061459  12.595065
# 52297    52298  416.075940      411.584070    15.313979  12.595065
# 52298    52299  432.883430      412.433039   -10.848526  12.595065
# 52299    52300  364.120124      416.360220    -6.471336  12.595065
#
#        success_count  success_rate  jet_fires  average_jet_fires  \
# 52295             50           1.0         43              40.98
# 52296             50           1.0         42              41.12
# 52297             50           1.0         50              41.46
# 52298             50           1.0         50              41.46
# 52299             50           1.0         38              41.22
#
#        policy_entropy  average_policy_entropy  effective_actions  \
# 52295        1.011561                1.012951           2.749889
# 52296        1.014203                1.013221           2.757165
# 52297        1.033953                1.013161           2.812160
# 52298        1.035754                1.013404           2.817230
# 52299        1.007087                1.016660           2.737614
#
#        average_effective_actions  steps  success failure_reason  \
# 52295                   2.753716     96     True           None
# 52296                   2.754459     95     True           None
# 52297                   2.754295    106     True           None
# 52298                   2.754962     90     True           None
# 52299                   2.763948     87     True           None
#
#        batch_rtg_mean  batch_rtg_std  elapsed_seconds
# 52295       676.75061     149.345932              NaN
# 52296       676.75061     149.345932              NaN
# 52297       676.75061     149.345932              NaN
# 52298       676.75061     149.345932              NaN
# 52299       676.75061     149.345932       7100.21829

# %% [markdown]
# The rest of the code is the same as in the [single-trajectory REINFORCE notebook](https://github.com/aburkov/theDRLbook/blob/main/gamma_dropped_rtg_reinforce_colab.ipynb):

# %%
from IPython.display import HTML, display
from matplotlib.animation import FuncAnimation


def rollout_frames(
    policy: Policy,
    *,
    seed: int = SEED + 10_000,
    max_steps: int = MAX_STEPS,
) -> tuple[list[np.ndarray], list[float], float, dict]:
    policy.eval()
    rng = np.random.default_rng(seed)
    env = PlatformLander(**platform_lander_kwargs(render_mode='rgb_array'))

    frames: list[np.ndarray] = []
    rewards: list[float] = []
    info: dict = {}
    terminated = False
    truncated = False

    try:
        observation, _ = env.reset(seed=int(rng.integers(0, 2**31 - 1)))
        observation = randomize_start(
            env,
            rng,
            random_booster_start_x=RANDOM_BOOSTER_START_X,
        )

        with torch.no_grad():
            for _ in range(max_steps):
                action = sample_action(policy, observation, train=False)
                observation, reward, terminated, truncated, info = env.step(action)
                rewards.append(float(reward))
                frames.append(env.render())

                if terminated or truncated:
                    break

        if rewards and not terminated and not truncated:
            rewards[-1] = float(env.failure_reward)
            info = {
                **info,
                'success': False,
                'failure_reason': 'timeout',
            }
    finally:
        env.close()

    return frames, rewards, discounted_return(rewards, GAMMA), info


def show_rollout(policy: Policy, *, fps: int = 30) -> None:
    frames, rewards, episode_return, info = rollout_frames(policy)

    print(
        f'evaluation_return={episode_return:.2f} '
        f'undiscounted={sum(rewards):.2f} '
        f'steps={len(rewards)} '
        f'info={info}'
    )

    if not frames:
        print('No frames were rendered.')
        return

    fig, ax = plt.subplots(figsize=(6, 4))
    ax.axis('off')
    image = ax.imshow(frames[0])

    def update(frame: np.ndarray):
        image.set_data(frame)
        return (image,)

    anim = FuncAnimation(
        fig,
        update,
        frames=frames,
        interval=1000 / fps,
        blit=True,
    )
    plt.close(fig)
    display(HTML(anim.to_jshtml()))


show_rollout(policy)
# Out:
# evaluation_return=394.20 undiscounted=940.53 steps=89 info={'success': True, 'failure_reason': None, 'platform_x': 9.494576454162598, 'platform_impact_velocity': (2.1856800317764282, -6.691892147064209, -0.9623016715049744), 'success_reward_multiplier': 0.7967181376048497, 'wind_power': 3.0, 'wind_direction': (1.0, 0.0), 'jet_fires_used': 4, 'jet_fires_remaining': 46, 'stable_landing_steps': 0, 'anchored_feet': ('left_foot', 'right_foot'), 'left_foot_contact': True, 'right_foot_contact': True, 'body_platform_contact': False, 'platform_contact': True}
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgbff285a0f9bf4036a009055cf8ef50d9">
#   <div class="anim-controls">
#     <input id="_anim_sliderbff285a0f9bf4036a009055cf8ef50d9" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animbff285a0f9bf4036a009055cf8ef50d9.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animbff285a0f9bf4036a009055cf8ef50d9.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animbff285a0f9bf4036a009055cf8ef50d9.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animbff285a0f9bf4036a009055cf8ef50d9.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animbff285a0f9bf4036a009055cf8ef50d9.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animbff285a0f9bf4036a009055cf8ef50d9.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animbff285a0f9bf4036a009055cf8ef50d9.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animbff285a0f9bf4036a009055cf8ef50d9.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animbff285a0f9bf4036a009055cf8ef50d9.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animbff285a0f9bf4036a009055cf8ef50d9.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectbff285a0f9bf4036a009055cf8ef50d9"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_bff285a0f9bf4036a009055cf8ef50d9"
#              >
#       <label for="_anim_radio1_bff285a0f9bf4036a009055cf8ef50d9">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_bff285a0f9bf4036a009055cf8ef50d9"
#              checked>
#       <label for="_anim_radio2_bff285a0f9bf4036a009055cf8ef50d9">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_bff285a0f9bf4036a009055cf8ef50d9"
#              >
#       <label for="_anim_radio3_bff285a0f9bf4036a009055cf8ef50d9">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgbff285a0f9bf4036a009055cf8ef50d9";
#     var slider_id = "_anim_sliderbff285a0f9bf4036a009055cf8ef50d9";
#     var loop_select_id = "_anim_loop_selectbff285a0f9bf4036a009055cf8ef50d9";
#     var frames = new Array(89);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjAsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvlHJYcgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAFH9JR

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].plot(history['episode'], history['return'], alpha=0.35, label='return')
axes[0].plot(history['episode'], history['average_return'], label=f'avg{TARGET_WINDOW}')
axes[0].set_title('Return')
axes[0].set_xlabel('Episode')
axes[0].legend()

axes[1].plot(history['episode'], history['success_rate'])
axes[1].set_title(f'Success rate over last {TARGET_WINDOW}')
axes[1].set_xlabel('Episode')
axes[1].set_ylim(-0.05, 1.05)

plt.tight_layout()
plt.show()

# %% [markdown]
# After training, we can run the learned policy greedily and render one RGB frame. In Colab, rendering to a Pygame window is not convenient, so this cell uses `render_mode="rgb_array"` and displays the final frame with Matplotlib.

# %%
def evaluate_policy(policy: Policy, *, seed: int = SEED + 10_000, max_steps: int = MAX_STEPS) -> tuple[list[np.ndarray], list[float], float, dict]:
    rng = np.random.default_rng(seed)
    env = PlatformLander(**platform_lander_kwargs(render_mode='rgb_array'))

    frames: list[np.ndarray] = []
    rewards: list[float] = []
    info: dict = {}

    try:
        observation, _ = env.reset(seed=int(rng.integers(0, 2**31 - 1)))
        observation = randomize_start(
            env,
            rng,
            random_booster_start_x=RANDOM_BOOSTER_START_X,
        )

        for _ in range(max_steps):
            action = sample_action(policy, observation, train=False)
            observation, reward, terminated, truncated, info = env.step(action)
            rewards.append(float(reward))
            frames.append(env.render())
            if terminated or truncated:
                break

        if rewards and not terminated and not truncated:
            rewards[-1] = float(env.failure_reward)
            info = {
                **info,
                'success': False,
                'failure_reason': 'timeout',
            }
    finally:
        env.close()

    return frames, rewards, discounted_return(rewards, GAMMA), info


frames, rewards, episode_return, info = evaluate_policy(policy)
print(f'evaluation_return={episode_return:.2f} steps={len(rewards)} info={info}')

if frames:
    plt.figure(figsize=(6, 4))
    plt.imshow(frames[-1])
    plt.axis('off')
    plt.show()
# Out:
# evaluation_return=394.20 steps=89 info={'success': True, 'failure_reason': None, 'platform_x': 9.494576454162598, 'platform_impact_velocity': (2.1856800317764282, -6.691892147064209, -0.9623016715049744), 'success_reward_multiplier': 0.7967181376048497, 'wind_power': 3.0, 'wind_direction': (1.0, 0.0), 'jet_fires_used': 4, 'jet_fires_remaining': 46, 'stable_landing_steps': 0, 'anchored_feet': ('left_foot', 'right_foot'), 'left_foot_contact': True, 'right_foot_contact': True, 'body_platform_contact': False, 'platform_contact': True}
